# %% [markdown]
# <a href="https://colab.research.google.com/github/belogabriel/pandas_lib/blob/main/amostragempract_gabrielbelo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #
# **Assignment - Amostragem**

# %% [markdown]
# ### Utilize a base de dados Iris (“toy dataset” – base de dados para fins educativos) para replicar alguns tipos de amostragem.

# %%
import pandas as pd
from sklearn import datasets
from scipy.stats import norm
import scipy.stats as st
import numpy as np
import os
import random

# %%
iris_df = pd.DataFrame(datasets.load_iris().data)

# %%
iris_df.columns = datasets.load_iris().feature_names

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ### Parte prática no Colab!

# %% [markdown]
# ### 1. Faça uma Amostragem aleatória simples: 20 itens
# ### 2. Faça uma Amostragem de Julgamento: itens com “petal width” maior que 2.0
# ### 3. Faça uma Amostragem de Conveniência: primeiros 30 itens

# %%
# QUESTÃO 1

idx = np.arange(len(iris_df))
random_sample_idx = random.sample(list(idx), k=20)
random.seed(10)
random_sample_idx
# Out:
# [129,
#  58,
#  111,
#  15,
#  54,
#  40,
#  42,
#  41,
#  139,
#  87,
#  91,
#  121,
#  10,
#  122,
#  97,
#  105,
#  116,
#  59,
#  23,
#  110]

# %%
# QUESTÃO 2


gt20 = iris_df[iris_df["petal width (cm)"] > 2.0]


gt20.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 100                6.3               3.3                6.0               2.5
# 102                7.1               3.0                5.9               2.1
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 109                7.2               3.6                6.1               2.5

# %%
# QUESTÃO 3

iris_df.head(31)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# 11                4.8               3.4                1.6               0.2
# 12                4.8               3.0                1.4               0.1
# 13                4.3               3.0                1.1               0.1
# 14                5.8               4.0                1.2               0.2
# 15                5.7               4.4                1.5               0.4
# 16                5.4               3.9                1.3               0.4
# 17                5.1               3.5                1.4               0.3
# 18                5.7               3.8                1.7               0.3
# 19                5.1               3.8                1.5               0.3
# 20                5.4               3.4                1.7               0.2
# 21                5.1               3.7                1.5               0.4
# 22                4.6               3.6                1.0               0.2
# 23                5.1               3.3                1.7               0.5
# 24                4.8               3.4                1.9               0.2
# 25                5.0               3.0                1.6               0.2
# 26                5.0               3.4                1.6               0.4
# 27                5.2               3.5                1.5               0.2
# 28                5.2               3.4                1.4               0.2
# 29                4.7               3.2                1.6               0.2
# 30                4.8               3.1                1.6               0.2
